# %% [markdown]
# # SharpPlot Notebook
# ### Plot data using SharpPlot in Dyalog APL

# %%
⍝ Define some terms
sin ← 1∘○
pi ← ○

# %% [markdown]
# **A Fourier Series is a sum of sinusoidal (sine and cosine) waves**
#
# Fourier series sawtooth wave:
# $$\sum_{n=1}^{\infty} {{1}\over{n}} \sin (n\pi x)$$
# Square wave:
# $$\sum_{n=1,3,5,...}^{\infty} {1\over n}\sin(n\pi x)$$
#
# **The formula is easily tranlasted into APL:**
# $1\over n$ ≡ <code>(÷n)</code>
# $\sum$ ≡ <code>+/</code>
# $\sin(n\pi x)$ ≡ <code>1○○n×x</code>
#
# **Below we are going to graph these functions:**

# %%
⍝ f(x) = +/ (÷n) × sin (n pi x)

n ← ⍳5 ⍝ n from 1 to 5
Pi ← {○(÷⍵)×⍳⍺×⍵} ⍝ numbers 0 to ⍺ in steps of size ⍵
x ← 2 Pi 100 ⍝ x from 0 to 2×pi
F ← {(÷⍵) × sin ⍵ × pi x} ⍝ The fourier series as described above

# %%
⍝ Load and initialise SharpPlot
)copy sharpplot
InitCauseway⍬
# Out:
# <span style="white-space:pre; font-family: monospace">C:\Program Files\Dyalog\Dyalog APL-64 17.1 Unicode\ws\sharpplot.dws saved Sat Feb  9 20:02:56 2019
# </span>

# %%
∇ r ← plot data;sp;d ⍝ Draw a line graph from data
  :Trap 0
    sp ← ⎕NEW Causeway.SharpPlot
    :For data :In data
    sp.DrawLineGraph ⊆ data
    :EndFor
    r ← 'Plotted data'
    View sp
  :Else
    r ← 'Could not plot data'
  :EndTrap
∇

# %% [markdown]
# ### Below: create a vector of integers 1 2 3 4 5

# %%
⍳5
# Out:
# <span style="white-space:pre; font-family: monospace">1 2 3 4 5
# </span>

# %% [markdown]
# ### Then: create a vector of only odd integers 1 3 5 7 9

# %%
¯1 + 2×⍳5
# Out:
# <span style="white-space:pre; font-family: monospace">1 3 5 7 9
# </span>

# %% [markdown]
# ### **The code below plots a sawtooth wave with 5 terms:**
# ## **Task:** Modify the code to plot:
# 1. Sawtooth wave with **30, 100, 1000** terms
# 2. A square wave with **3, 30, 100, 1000** terms
# 3. Plot the **individual sine waves**, instead of their sum
# ## and **note** what **changes**

# %%
n ← ¯1 + 2×⍳5
x ← 2 Pi 500
plot (+/F¨n),F¨n
# Out:
# <svg version="1.1" baseProfile="full" width="100%" height="100%" viewBox="0 0 4320 3240"  xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:ev="http://www.w3.org/2001/xml-events" >
# <desc>Created by Causeway SVG engine - SharpPlot v3.61.0</desc>
# <g stroke-miterlimit="100">
# <desc>Paint the paper =====</desc>
#  <g fill="White" >
#   <rect x="0" y="0" width="4320" height="3240" />
#  </g>
# <desc>Border =====</desc>
# <desc>Region =====</desc>
# <desc>X-Axis Ticks =====</desc>
# <desc>X-Axis tickmarks</desc>
#  <path fill="none" stroke-width="7.2" stroke="Black" d="M400 2720L400 2764M770 2720L770 2764M1140 2720L1140 2764M1510 2720L1510 2764M1880 2720L1880 2764M2250 2720L2250 2764M2620 2720L2620 2764M2990 2720L2990 2764M3360 2720L3360 2764M3730 2720L3730 2764M4100 2720L4100 2764"/>
# <desc>Y-Axis Ticks =====</desc>
# <desc>Y-Axis tickmarks</desc>
#  <path fill="none" stroke-width="7.2" stroke="Black" d="M400 2720L367 2720M400 2494L367 2494M400 2268L367 2268M400 2042L367 2042M400 1816L367 1816M400 1590L367 1590M400 1364L367 1364M400 1138L367 1138M400 912L367 912M400 686L367 686M400 460L367 460"/>
# <desc>Axes =====</desc>
#  <path fill="none" stroke-width="12" stroke="Black" d="M400 2764L400 416M356 2720L4144 2720"/>
# <desc>Y-axis labels</desc>
#  <g font-family="Times New Roman" font-size="80" text-anchor="end" >
#   <text x="335" y="2740" >-1</text>
#   <text x="335" y="2514" >-0.8</text>
#   <text x="335" y="2288" >-0.6</text>
#   <text x="335" y="2062" >-0.4</text>
#   <text x="335" y="1836" >-0.2</text>
#   <text x="335" y="1610" >0</text>
#   <text x="335" y="1384" >0.2</text>
#   <text x="335" y="1158" >0.4</text>
#   <text x="335" y="932" >0.6</text>
#   <text x="335" y="706" >0.8</text>
#   <text x="335" y="480" >1</text>
#  </g>
# <desc>for X-axis labels</desc>
#  <g font-family="Times New Roman" font-size="80" text-anchor="middle" >
#   <text x="400" y="2844" >0</text>
#   <text x="770" y="2844" >100</text>
#   <text x="1140" y="2844" >200</text>
#   <text x="1510" y="2844" >300</text>
#   <text x="1880" y="2844" >400</text>
#   <text x="2250" y="2844" >500</text>
#   <text x="2620" y="2844" >600</text>
#   <text x="2990" y="2844" >700</text>
#   <text x="3360" y="2844" >800</text>
#   <text x="3730" y="2844" >900</text>
#   <text x="4100" y="2844" >1000</text>
#  </g>
# <desc>Heading, subheading and footnotes =====</desc>
# <desc>Start of Line Chart ===========</desc>
# <desc>Points follow ...</desc>
# <desc>Line</desc>
#  <g stroke-width="3" stroke="Navy" stroke-linejoin="round" stroke-linecap="round" fill="none" >
#   <path d="M4100 644L4096 652 4093 663 4089 676 4085 690 4082 705 4078 721 4074 737 4070 752 4067 765 4063 777 4059 786 4056 792 4052 795 4048 794 4045 789 4041 780 4037 768 4033 752 4030 733 4026 711 4022 687 4019 662 4015 637 4011 613 4008 591 4004 571 4000 556 3996 545 3993 541 3989 543 3985 554 3982 572 3978 600 3974 638 3971 684 3967 741 3963 807 3959 881 3956 964 3952 1055 3948 1152 3945 1254 3941 1361 3937 1471 3934 1582 3930 1693 3926 1803 3922 1911 3919 2014 3915 2112 3911 2203 3908 2288 3904 2363 3900 2430 3897 2488 3893 2536 3889 2575 3885 2604 3882 2624 3878 2636 3874 2639 3871 2636 3867 2626 3863 2611 3860 2592 3856 2570 3852 2546 3848 2521 3845 2496 3841 2472 3837 2450 3834 2431 3830 2414 3826 2401 3823 2392 3819 2387 3815 2385 3811 2387 3808 2393 3804 2402 3800 2413 3797 2426 3793 2441 3789 2457 3786 2472 3782 2488 3778 2502 3774 2515 3771 2526 3767 2535 3763 2542 3760 2545 3756 2546 3752 2544 3749 2540 3745 2533 3741 2524 3737 2514 3734 2503 3730 2490 3726 2478 3723 2465 3719 2454 3715 2443 3712 2434 3708 2427 3704 2422 3700 2419 3697 2419 3693 2421 3689 2425 3686 2431 3682 2438 3678 2448 3675 2458 3671 2469 3667 2480 3663 2491 3660 2502 3656 2511 3652 2519 3649 2526 3645 2530 3641 2533 3638 2533 3634 2531 3630 2527 3626 2522 3